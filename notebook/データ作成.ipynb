# %%
import sys
import os
import shutil
import pprint

pprint.pprint(sys.path)
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
#sys.path.append('/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/src')

# %%
import imp
import create_sample_data

imp.reload(create_sample_data)
# Out:
# <module 'create_sample_data' from '/content/create_sample_data.py'>

# %%
create_data = create_sample_data.CreateSampleData(['0', '1', '2', '3', '4'], convert_size=(112, 28), thresh=140, x_step=1)
#リサイズの大きさは、MNISTに合わせて、(112, 28)とした

# %%
input_file_path = '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/カレンダー画像＿大岡/am3/2 am3.JPG'
output_path = '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/文字分割教師データ/data_03'

# %%
convert_img = create_data.convert_img(input_file_path=input_file_path)

# %%
create_data.generate_data_automatically(convert_img)
# Out:
# {'0': [<PIL.Image.Image image mode=L size=28x28 at 0x7F987BD022D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD02190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD02990>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD028D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD02410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03650>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF030D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03990>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03110>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF033D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF036D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03B50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03E90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03F50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03590>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03210>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF035D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BF10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B590>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BC10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B2D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B890>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B710>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BD10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BBD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BC50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B990>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BFD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BD90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B8D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B0D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BA50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BCD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BA10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6BA90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B7D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B550>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B9D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B4D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B950>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B5D0>],
#  '1': [<PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03B90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03F90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03A90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03550>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03710>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF038D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03F10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03AD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03390>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03CD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03ED0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03DD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03A10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03B10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF039D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03690>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BCDE6D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BCA6690>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BCDEC90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF03C10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B6D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B790>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B1D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B690>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B150>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B650>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD6B110>],
#  '2': [],
#  '3': [],
#  '4': []}

# %%
create_data.save_data(output_path=output_path)
label_file_num_dict = {}
for label in ['0', '1', '2', '3', '4']:
    output_label_path = os.path.join(output_path, label)
    label_file_num_dict[label] = sum(os.path.isfile(os.path.join(output_label_path, name)) for name in os.listdir(output_label_path))  # ラベルディレクトリごとのファイル数を数え、辞書に格納
label_file_num_dict
# Out:
# {'0': 586, '1': 418, '2': 4, '3': 0, '4': 0}

# %%
create_data.generate_data_by_manual(convert_img)
# Out:
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 2
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# ['0', '1', '2', '3', '4']の中から選択してください
# a
# {'0': [<PIL.Image.Image image mode=L size=28x28 at 0x7F987BE340D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BAF8910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BADAF90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BBE4C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C0AC950>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD8C510>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD8CA90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD8C690>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD8C450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BCF39D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD8C2D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC0DC90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC2E110>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC2E250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE2ED90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BFA1710>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD13C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC2EBD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC81A10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF85950>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF6AD90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC5B850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE8BE90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC3DCD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BB95E50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC63AD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BA8B050>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD00DD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD00410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF85FD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC71C10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F98803FBB90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE22E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD137D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BB60E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C05B390>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BAF1210>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BB00810>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BADA6D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F9880409E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F9880374390>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF38F50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C1C3D50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C5824D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BCB9CD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BADA190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD22090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF38310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C0888D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C0885D0>],
#  '1': [<PIL.Image.Image image mode=L size=28x28 at 0x7F987BAD9310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BDEDB90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BB228D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BB4AE10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE22C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC2E190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BA8B110>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF1D7D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BDD1410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BAC73D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD13490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD22590>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BABD310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BAC7CD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC2E8D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BABD590>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BABDA90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE82A10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE82790>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE82250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE82750>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BE823D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC3DDD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC3D050>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BDD1490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC63450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF6F2D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BC3DAD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BF4DFD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD00D10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987BD00890>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C02D450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7F987C116050>],
#  '2': [<PIL.Image.Image image mode=L size=28x28 at 0x7F987BE56690>],
#  '3': [],
#  '4': []}

# %%
create_data.save_data(output_path=output_path)
label_file_num_dict = {}
for label in ['0', '1', '2', '3', '4']:
    output_label_path = os.path.join(output_path, label)
    label_file_num_dict[label] = sum(os.path.isfile(os.path.join(output_label_path, name)) for name in os.listdir(output_label_path))  # ラベルディレクトリごとのファイル数を数え、辞書に格納
label_file_num_dict
# Out:
# {'0': 298, '1': 202, '2': 4, '3': 0, '4': 0}

# %%
shutil.make_archive('data_02', 'zip', root_dir='/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/文字分割教師データ/data_02')
# Out:
# '/content/data_02.zip'

# %%
from PIL import Image
import matplotlib.pyplot as plt
import glob
# %matplotlib inline

file_list = glob.glob('/content/auto/1/*.jpg')
for f in file_list:
    test_img = Image.open(f)
    plt.imshow(test_img)
    plt.gray()
    plt.show()

# %%
test_list = ['1', '2']
test = ''
test_a_list = test_list.append('a')
while test not in test_list.append('a'):
    test = input()
else:
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-2e52e4785d28> in <module>()
#       2 test = ''
#       3 test_a_list = test_list.append('a')
# ----> 4 while test not in test_list.append('a'):
#       5     test = input()
#       6 else:
#
# TypeError: argument of type 'NoneType' is not iterable

# %%
test_list
# Out:
# ['1', '2', 'a', 'a', 'a']
