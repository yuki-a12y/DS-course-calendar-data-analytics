# %%
import sys
import os
import shutil
import pprint

pprint.pprint(sys.path)
# Out:
# ['',
#  '/content',
#  '/env/python',
#  '/usr/lib/python37.zip',
#  '/usr/lib/python3.7',
#  '/usr/lib/python3.7/lib-dynload',
#  '/usr/local/lib/python3.7/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.7/dist-packages/IPython/extensions',
#  '/root/.ipython',
#  '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/src']

# %%
sys.path.append('/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/src')

# %%
import imp
import create_sample_data

imp.reload(create_sample_data)
# Out:
# <module 'create_sample_data' from '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/src/create_sample_data.py'>

# %%
create_data = create_sample_data.CreateSampleData(['0', '1', '2', '3', '4'], convert_size=(112, 28), thresh=140, x_step=1)
#リサイズの大きさは、MNISTに合わせて、(112, 28)とした

# %%
input_file_path = '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/カレンダー画像＿大岡/am1/9 am1.JPG'
output_path = '/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/文字分割教師データ/data_02'

# %%
convert_img = create_data.convert_img(input_file_path=input_file_path)

# %%
create_data.auto_create_data(convert_img)
# Out:
# {'0': [<PIL.Image.Image image mode=L size=28x28 at 0x7FB367820550>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36783B790>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36783B910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36783BAD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36783B6D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367800610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36783BC10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A950>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AB90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AA90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711B50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677110D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711810>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711DD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711A50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739D90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739B90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677392D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739A10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739D10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739650>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739350>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677390D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739290>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739CD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676767D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676765D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676766D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676B50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676B90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676763D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676E90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676D50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676CD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753B250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753B2D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753BED0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753B9D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753B510>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753BB90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753B390>],
#  '1': [<PIL.Image.Image image mode=L size=28x28 at 0x7FB36783BED0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A6D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A7D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AA50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AD90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A290>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AAD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A490>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AE50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AD10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AB50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766AF50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766ADD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A8D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36766A1D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367965910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367965A90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367965990>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711D10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711650>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711D90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711350>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711290>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677115D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367711750>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367739510>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367676C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676761D0>],
#  '2': [],
#  '3': [],
#  '4': []}

# %%
create_data.save_data(output_path=output_path)
label_file_num_dict = {}
for label in ['0', '1', '2', '3', '4']:
    output_label_path = os.path.join(output_path, label)
    label_file_num_dict[label] = sum(os.path.isfile(os.path.join(output_label_path, name)) for name in os.listdir(output_label_path))  # ラベルディレクトリごとのファイル数を数え、辞書に格納
label_file_num_dict
# Out:
# {'0': 1359, '1': 990, '2': 3, '3': 0, '4': 0}

# %%
create_data.create_data(convert_img)
# Out:
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 2
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 1
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# ['0', '1', '2', '3', '4']の中から選択してください
# 0
# {'0': [<PIL.Image.Image image mode=L size=28x28 at 0x7FB367933890>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367660290>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367438B90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36749BD50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3673E8410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36791D850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3678E6D10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677D9D10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36749BDD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367777F90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3678B99D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367516E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367416C90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367758C50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367924190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36740E610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676769D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367672610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753DD90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36787C090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3678AEC10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36749BE50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367771E90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3675570D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367686BD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36755B850>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367652E90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36E3DADD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367435210>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3678436D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367435890>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3674A5BD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3674F7250>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3678F8050>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677C6A50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3677D9410>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367EE4E10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367E4C050>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367F97090>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36A1F8E50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36785A190>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36785AC10>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3674DD150>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367551710>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36744BD90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367443DD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3674CB7D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3675ABE90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367F0A550>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367771550>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367435750>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367EA4390>],
#  '1': [<PIL.Image.Image image mode=L size=28x28 at 0x7FB3678B1350>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3679266D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367915BD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367822210>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3674CB1D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3675627D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367884E50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676D6910>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36755EB50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3675635D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367510E50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36755ED90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB3676F4FD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367505390>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367933A50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367571FD0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36752E2D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36746CD50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367EFBB50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36791AA90>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36747A350>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36776F450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367672450>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36779D9D0>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367505150>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB36753D750>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367835310>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367669690>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367915610>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367841A50>,
#   <PIL.Image.Image image mode=L size=28x28 at 0x7FB367458F50>],
#  '2': [<PIL.Image.Image image mode=L size=28x28 at 0x7FB367F04F90>],
#  '3': [],
#  '4': []}

# %%
create_data.save_data(output_path=output_path)
label_file_num_dict = {}
for label in ['0', '1', '2', '3', '4']:
    output_label_path = os.path.join(output_path, label)
    label_file_num_dict[label] = sum(os.path.isfile(os.path.join(output_label_path, name)) for name in os.listdir(output_label_path))  # ラベルディレクトリごとのファイル数を数え、辞書に格納
label_file_num_dict
# Out:
# {'0': 971, '1': 706, '2': 3, '3': 0, '4': 0}

# %%
shutil.make_archive('data_02', 'zip', root_dir='/content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/文字分割教師データ/data_02')
# Out:
# '/content/data_02.zip'
