# %%
# !unzip /content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/カレンダー画像＿大岡.zip
# Out:
# Archive:  /content/drive/MyDrive/DS入門講座/手書きカレンダープロジェクト/data/カレンダー画像＿大岡.zip
#    creating: カレンダー画像/
#    creating: カレンダー画像/am1/
#   inflating: カレンダー画像/.DS_Store
#   inflating: __MACOSX/カレンダー画像/._.DS_Store
#    creating: カレンダー画像/am 2/
#    creating: カレンダー画像/am3/
#    creating: カレンダー画像/am4/
#    creating: カレンダー画像/am5/
#   inflating: カレンダー画像/am1/2 am1.JPG
#   inflating: カレンダー画像/am1/11 am1.JPG
#   inflating: カレンダー画像/am1/27 am1.JPG
#   inflating: カレンダー画像/am1/.DS_Store
#   inflating: __MACOSX/カレンダー画像/am1/._.DS_Store
#   inflating: カレンダー画像/am1/3 am1.JPG
#   inflating: カレンダー画像/am1/10 am1.JPG
#   inflating: カレンダー画像/am1/13 am.JPG
#   inflating: カレンダー画像/am1/25 am.JPG
#   inflating: カレンダー画像/am1/8 am1.JPG
#   inflating: カレンダー画像/am1/12 am1.JPG
#   inflating: カレンダー画像/am1/21 am.JPG
#   inflating: カレンダー画像/am1/17 am.JPG
#   inflating: カレンダー画像/am1/23 am.JPG
#   inflating: カレンダー画像/am1/19 am.JPG
#   inflating: カレンダー画像/am1/15 am.JPG
#   inflating: カレンダー画像/am1/9 am1.JPG
# ...

# %%
import matplotlib.pyplot as plt
from PIL import Image
# %matplotlib inline

# %%
img = Image.open('/content/カレンダー画像/am 2/10 am2.JPG')

# %%
imgs_dict = {'year':img}

# %%
plt.imshow(imgs_dict['year'])

# %%
img_dict = {'year':img, 'month':img, 'day':{'1':img, '15':img}}

# %%
img_dict['day']['1']
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=491x349 at 0x7FB085BBED50>

# %%
img_dict = {'year':img, 'month':img, 'day':{'1':[img, img, img], '15':[img, img, img]}}
