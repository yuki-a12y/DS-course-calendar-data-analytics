# %%
import sys

sys.path.append('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src')

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

import settings

# %matplotlib inline

# %%
import preprocessing
import imp

imp.reload(preprocessing)
# Out:
# <module 'preprocessing' from '/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src/preprocessing.py'>

# %%
calendar = cv2.imread('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/data/test_img/002.jpg')
#plt.figure(figsize=(20, 20))
#plt.imshow(calendar)

# %%
p = preprocessing.Preprocessing(original_calendar=calendar)

# %%
test_list = p.main()

# %%
plt.figure(figsize=(20, 20))
plt.imshow(p.threshold_calendar)

# %%
for i in range(35):
    for j in range(len(p.calendar_element_dict[i])):
        print('------------------')
        print(i)
        plt.imshow(p.calendar_element_dict[i][j])
        plt.gray()
        plt.show()
# Out:
# ------------------
# 3
# ------------------
# 3
# ------------------
# 3
# ------------------
# 3
# ------------------
# 4
# ------------------
# 4
# ------------------
# 4
# ------------------
# 5
# ------------------
# 5
# ------------------
# 5
# ------------------
# 6
# ------------------
# 6
# ------------------
# 6
# ------------------
# 7
# ------------------
# 7
# ------------------
# 7
# ------------------
# 8
# ------------------
# 8
# ------------------
# 8
# ------------------
# 9
# ------------------
# 9
# ------------------
# 9
# ------------------
# 10
# ------------------
# 10
# ------------------
# 10
# ------------------
# 11
# ------------------
# 11
# ------------------
# 11
# ------------------
# 12
# ------------------
# 12
# ------------------
# 12
# ------------------
# 12
# ------------------
# 12
# ------------------
# 13
# ------------------
# 13
# ------------------
# 13
# ------------------
# 13
# ------------------
# 14
# ------------------
# 14
# ...

# %%
a = 6
a = a / 2
type(a)
# Out:
# float
