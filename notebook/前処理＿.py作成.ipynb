# %%
import sys

sys.path.append('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src')

# %%
import cv2
import matplotlib.pyplot as plt
import settings

# %matplotlib inline

# %%
import preprocessing
import imp

imp.reload(preprocessing)
# Out:
# <module 'preprocessing' from '/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src/preprocessing.py'>

# %%
calendar = cv2.imread('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/data/preprocessing/calendar_screenshot.jpg')

# %%
calendar.shape
# Out:
# (450, 600, 3)

# %%
plt.imshow(calendar)

# %%
p = preprocessing.Preprocessing(original_calendar=calendar)

# %%
calendar = p.resize_calendar_1197_900(calendar=calendar)
plt.imshow(calendar)

# %%
calendar = p.detect_calendar_area(calendar, settings.TEMPLATE_PATH)
plt.figure(figsize=(10, 15))
plt.imshow(calendar)

# %%
year = calendar[50:90, 0:90]
plt.imshow(year)

# %%
year = calendar[35:95, 570:630]
plt.imshow(year)

# %%
day1 = calendar[183:230, 0:165]
plt.figure(figsize=(10, 30))
plt.imshow(day1)

# %%
day1 = calendar[183:230, 170:335]
plt.figure(figsize=(10, 30))
plt.imshow(day1)

# %%
week = []
for i in range(7):
    day = calendar[183:230, 2 + 171 * i:163 + 171 * i]
    week.append(day)
    plt.imshow(day)
    plt.show()

# %%
sunday = []
for i in range(5):
    day = calendar[185 + 137 * i:228 + 137 * i, 2:163]
    week.append(day)
    plt.imshow(day)
    plt.show()

# %%
day_dict = {}
for i in range(5):
    for j in range(7):
        day = calendar[185 + 137 * i:228 + 137 * i, 2 + 171 * j:163 + 171 * j]
        plt.imshow(day)
        plt.show()
        day_dict[(i + 1) * (j + 1)] = day

# %%
day_dict
# Out:
# {1: array([[[255, 255, 255],
#          [254, 254, 254],
#          [254, 254, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [254, 254, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         [[255, 255, 255],
#          [255, 255, 255],
#          [254, 254, 254],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [255, 255, 255]],
#
#         ...,
#
#         [[254, 254, 254],
#          [253, 253, 253],
#          [253, 253, 253],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [254, 254, 254]],
#
#         [[253, 253, 253],
#          [252, 252, 252],
#          [252, 252, 252],
#          ...,
#          [255, 255, 255],
#          [255, 255, 255],
#          [254, 254, 254]],
#
#         [[253, 253, 253],
# ...
