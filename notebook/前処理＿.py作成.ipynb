# %%
import sys

sys.path.append('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src')

# %%
import preprocessing
import imp

#imp.reload(preprocessing)

# %%
import cv2

# %%
calendar = cv2.imread('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/data/preprocessing/calendar_screenshot.jpg')

# %%
p = preprocessing.OverallPreprocessing(original_calendar=calendar)

# %%
p.main()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-670101fc2887> in <module>()
# ----> 1 p.main()
#
# /content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src/preprocessing.py in main(self)
#      18         calendar = self.detect_calendar_area(calendar, settings.TEMPLATE_PATH)
#      19         calendar = PreProcessForNN(calendar)
# ---> 20         self.calendar_element_list = divide_calendar(calendar)
#      21
#      22         return self.calendar_element_dict
#
# /content/drive/Othercomputers/マイ ノートパソコン/data_analytics/src/preprocessing.py in detect_calendar_area(self, calendar, template_path)
#      63         vertices_list = self.template_match(calendar=calendar, template_path=template_path)
#      64         self.homography_transformed_calendar = self.homography_transform(calendar=calendar, vertices_list=vertices_list)
# ...

# %%
test = cv2.imread('/content/drive/Othercomputers/マイ ノートパソコン/data_analytics/data/preprocessing/calendar_screenshot.jpg')

# %%
test.shape[0]
# Out:
# 450
